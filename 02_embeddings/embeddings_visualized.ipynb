# %% [markdown]
# # Word Embedding Explorer
# Finds nearest neighbours for query terms and visualises the results three ways:
# 1. **Bar chart** – similarity scores per term
# 2. **Scatter plot** – PCA projection of query + neighbour vectors
# 3. **Network graph** – relationship graph weighted by similarity

# %%
# !pip install gensim pandas matplotlib networkx scikit-learn adjustText
# Out:
# Requirement already satisfied: gensim in /opt/anaconda3/lib/python3.13/site-packages (4.4.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (3.10.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.13/site-packages (3.4.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.13/site-packages (1.6.1)
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy>=1.18.5 in /opt/anaconda3/lib/python3.13/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in /opt/anaconda3/lib/python3.13/site-packages (from gensim) (7.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.13/site-packages (from smart_open>=1.8.1->gensim) (1.17.0)
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: adjustText
# Successfully installed adjustText-1.3.0

# %%
# from gensim.models import KeyedVectors
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import networkx as nx
from sklearn.decomposition import PCA
from adjustText import adjust_text

# ── aesthetics ────────────────────────────────────────────────────────────────
plt.rcParams.update({
    "figure.facecolor": "#0d1117",
    "axes.facecolor":   "#161b22",
    "axes.edgecolor":   "#30363d",
    "axes.labelcolor":  "#c9d1d9",
    "xtick.color":      "#8b949e",
    "ytick.color":      "#8b949e",
    "text.color":       "#c9d1d9",
    "grid.color":       "#21262d",
    "grid.linewidth":   0.6,
    "font.family":      "monospace",
    "axes.titleweight": "bold",
})

PALETTE = ["#58a6ff", "#f78166", "#56d364", "#e3b341", "#bc8cff"]

# ── load model ────────────────────────────────────────────────────────────────
# model = KeyedVectors.load_word2vec_format("embeddings.bin", binary=True)
# For fastText: 
from gensim.models.fasttext import load_facebook_vectors
model = load_facebook_vectors("/Users/carmand/Desktop/RS/enp_embeddings/Shunpao/shunpao_300.bin")

query_terms = [
    "留美",
    "留學",
    "遊美",
]

TOPN = 20

# ── collect results ───────────────────────────────────────────────────────────
rows = []
for term in query_terms:
    if term not in model:
        rows.append({"query_term": term, "similar_term": None,
                     "similarity": None, "note": "term not in vocabulary"})
        continue
    for sim_term, score in model.most_similar(term, topn=TOPN):
        rows.append({"query_term": term, "similar_term": sim_term,
                     "similarity": score, "note": ""})

df = pd.DataFrame(rows)
df.to_csv("expanded_queries.csv", index=False, encoding="utf-8-sig")
print(df.to_string(index=False))
# Out:
# query_term similar_term  similarity note
#         留美         留美學生    0.713006
#         留美          留美生    0.697571
#         留美         留美大學    0.673395
#         留美         留美碩士    0.667989
#         留美         歐美學生    0.662810
#         留美          美學生    0.661857
#         留美          留美江    0.659519
#         留美         遊美學生    0.648579
#         留美         留美學界    0.631295
#         留美        留美公費生    0.629916
#         留美         游美學生    0.626720
#         留美        美國留學生    0.626453
#         留美         留美牙科    0.623529
#         留美        密希根大學    0.622888
#         留美        留美學生會    0.621088
#         留美      美國華盛頓大學    0.615730
#         留美         老留學生    0.612070
#         留美        哥敦根大學    0.611471
#         留美         留美華僑    0.610022
#         留美       美華盛頓大學    0.609377
#         留學           游學    0.807625
#         留學          留學生    0.757372
#         留學           遊學    0.745259
#         留學          國留學    0.737263
#         留學          華留學    0.730468
#         留學          留學。    0.729782
#         留學          留學日    0.727623
#         留學         老留學生    0.718794
#         留學         公費留學    0.714825
#         留學          東留學    0.708669
#         留學           官費    0.704027
#         留學         外國留學    0.702516
#         留學         出國留學    0.700406
#         留學           自費    0.696168
#         留學        出國留學生    0.694631
#         留學         留學生界    0.694273
#         留學          洋留學    0.693498
#         留學          留學丶    0.690966
#         留學         美國留學    0.690068
#         留學         美留學生    0.688059
#         遊美         遊美學生    0.636842
#         遊美        遊美學務處    0.621203
#         遊美          留美生    0.590229
#         遊美          蘭金君    0.590128
#         遊美        游美學務處    0.589225
#         遊美         游美學生    0.587129
#         遊美          游美生    0.581269
#         遊美          遊學部    0.573912
#         遊美        歐洲留學生    0.571669
#         遊美          英語學    0.570483
#         遊美      本薛凡尼亞大學    0.568514
#         遊美         美學務處    0.567143
#         遊美          本舉期    0.565201
#         遊美        留美公費生    0.565156
#         遊美         留美大學    0.564478
#         遊美        阿海阿大學    0.563960
#         遊美        康撒斯大學    0.563440
#         遊美         實習敎授    0.560522
#         遊美         留美學界    0.558601
#         遊美       美國耶路大學    0.557782

# %% [markdown]
# ## Visualisation 1 — Similarity Bar Charts
# One subplot per query term, bars ranked by cosine similarity.

# %%
valid_terms = [t for t in query_terms if t in model]
ncols = len(valid_terms)

fig, axes = plt.subplots(1, ncols, figsize=(6 * ncols, 7),
                         sharey=False, constrained_layout=True)
fig.suptitle("Top Similar Terms by Cosine Similarity", fontsize=14, y=1.02)

if ncols == 1:
    axes = [axes]

for ax, term, color in zip(axes, valid_terms, PALETTE):
    subset = df[df["query_term"] == term].dropna(subset=["similarity"])
    subset = subset.sort_values("similarity", ascending=True)  # ascending so highest is at top

    bars = ax.barh(subset["similar_term"], subset["similarity"],
                   color=color, alpha=0.85, height=0.65)

    # value labels
    for bar, val in zip(bars, subset["similarity"]):
        ax.text(bar.get_width() + 0.002, bar.get_y() + bar.get_height() / 2,
                f"{val:.3f}", va="center", ha="left",
                fontsize=7.5, color="#8b949e")

    ax.set_title(f'"{term}"', color=color, fontsize=12)
    ax.set_xlabel("Cosine similarity")
    ax.set_xlim(subset["similarity"].min() - 0.02,
                subset["similarity"].max() + 0.04)
    ax.grid(axis="x", linestyle="--")
    ax.tick_params(axis="y", labelsize=8)
    ax.spines[["top", "right"]].set_visible(False)

plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
            facecolor=fig.get_facecolor())
plt.show()
print("Saved → viz1_bar_charts.png")
# Out:
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 32654 (\N{CJK UNIFIED IDEOGRAPH-7F8E}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 33775 (\N{CJK UNIFIED IDEOGRAPH-83EF}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 30427 (\N{CJK UNIFIED IDEOGRAPH-76DB}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 38931 (\N{CJK UNIFIED IDEOGRAPH-9813}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 30041 (\N{CJK UNIFIED IDEOGRAPH-7559}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 20689 (\N{CJK UNIFIED IDEOGRAPH-50D1}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 21733 (\N{CJK UNIFIED IDEOGRAPH-54E5}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 25958 (\N{CJK UNIFIED IDEOGRAPH-6566}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 26681 (\N{CJK UNIFIED IDEOGRAPH-6839}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 32769 (\N{CJK UNIFIED IDEOGRAPH-8001}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz1_bar_charts.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/389749230.py:32: UserWarning: Glyph
) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34389 (\N{CJK UNIFIED IDEOGRAPH-8655}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34203 (\N{CJK UNIFIED IDEOGRAPH-859B}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20961 (\N{CJK UNIFIED IDEOGRAPH-51E1}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20126 (\N{CJK UNIFIED IDEOGRAPH-4E9E}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27954 (\N{CJK UNIFIED IDEOGRAPH-6D32}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 37096 (\N{CJK UNIFIED IDEOGRAPH-90E8}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34349 (\N{CJK UNIFIED IDEOGRAPH-862D}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21531 (\N{CJK UNIFIED IDEOGRAPH-541B}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# Saved → viz1_bar_charts.png

# %% [markdown]
# ## Visualisation 2 — PCA Scatter Plot
# Projects high-dimensional vectors down to 2-D with PCA.
# Query terms are shown as large filled markers; their neighbours as smaller ones, colour-coded by query.

# %%
# collect all words to project
all_words, word_meta = [], {}   # meta: {word: {"query": str, "is_query": bool}}
for term in valid_terms:
    if term not in all_words:
        all_words.append(term)
        word_meta[term] = {"query": term, "is_query": True}
    for sim_term, _ in model.most_similar(term, topn=TOPN):
        if sim_term not in word_meta:
            all_words.append(sim_term)
            word_meta[sim_term] = {"query": term, "is_query": False}

# stack vectors, run PCA
vectors = np.vstack([model[w] for w in all_words])
pca = PCA(n_components=2, random_state=42)
coords = pca.fit_transform(vectors)
var = pca.explained_variance_ratio_ * 100

fig, ax = plt.subplots(figsize=(11, 8))
fig.suptitle("PCA Projection of Query Terms & Nearest Neighbours", fontsize=13)

texts = []
for i, word in enumerate(all_words):
    meta = word_meta[word]
    q_idx = valid_terms.index(meta["query"])
    color = PALETTE[q_idx]
    is_q = meta["is_query"]

    ax.scatter(coords[i, 0], coords[i, 1],
               c=color, s=220 if is_q else 60,
               marker="*" if is_q else "o",
               zorder=4 if is_q else 3,
               alpha=1.0 if is_q else 0.65,
               edgecolors="#ffffff" if is_q else "none",
               linewidths=0.8)

    fontsize = 9 if is_q else 7
    weight = "bold" if is_q else "normal"
    texts.append(ax.text(coords[i, 0], coords[i, 1], word,
                         fontsize=fontsize, fontweight=weight,
                         color=color if is_q else "#8b949e"))

# repel overlapping labels
adjust_text(texts, ax=ax, arrowprops=dict(arrowstyle="-", color="#30363d", lw=0.5))

legend_handles = [mpatches.Patch(facecolor=PALETTE[i], label=t)
                  for i, t in enumerate(valid_terms)]
ax.legend(handles=legend_handles, title="Query", loc="upper left",
          framealpha=0.3, fontsize=9, title_fontsize=9)

ax.set_xlabel(f"PC 1  ({var[0]:.1f}% var)")
ax.set_ylabel(f"PC 2  ({var[1]:.1f}% var)")
ax.grid(True, linestyle="--")
ax.spines[["top", "right"]].set_visible(False)

plt.tight_layout()
plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
            facecolor=fig.get_facecolor())
plt.show()
print("Saved → viz2_pca_scatter.png")
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 30041 (\N{CJK UNIFIED IDEOGRAPH-7559}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 32654 (\N{CJK UNIFIED IDEOGRAPH-7F8E}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 30889 (\N{CJK UNIFIED IDEOGRAPH-78A9}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 22763 (\N{CJK UNIFIED IDEOGRAPH-58EB}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 27472 (\N{CJK UNIFIED IDEOGRAPH-6B50}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 27743 (\N{CJK UNIFIED IDEOGRAPH-6C5F}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 36938 (\N{CJK UNIFIED IDEOGRAPH-904A}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 30028 (\N{CJK UNIFIED IDEOGRAPH-754C}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 36027 (\N{CJK UNIFIED IDEOGRAPH-8CBB}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 29273 (\N{CJK UNIFIED IDEOGRAPH-7259}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 31185 (\N{CJK UNIFIED IDEOGRAPH-79D1}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 23494 (\N{CJK UNIFIED IDEOGRAPH-5BC6}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 24076 (\N{CJK UNIFIED IDEOGRAPH-5E0C}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 26681 (\N{CJK UNIFIED IDEOGRAPH-6839}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph 26371 (\N{CJK UNIFIED IDEOGRAPH-6703}) missing from font(s) DejaVu Sans Mono.
#   ax.figure.draw_without_rendering()
# /opt/anaconda3/lib/python3.13/site-packages/adjustText/__init__.py:419: UserWarning: Glyph
) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 20022 (\N{CJK UNIFIED IDEOGRAPH-4E36}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 37096 (\N{CJK UNIFIED IDEOGRAPH-90E8}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 27954 (\N{CJK UNIFIED IDEOGRAPH-6D32}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 34203 (\N{CJK UNIFIED IDEOGRAPH-859B}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 20961 (\N{CJK UNIFIED IDEOGRAPH-51E1}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 20126 (\N{CJK UNIFIED IDEOGRAPH-4E9E}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 38463 (\N{CJK UNIFIED IDEOGRAPH-963F}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 28023 (\N{CJK UNIFIED IDEOGRAPH-6D77}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 25746 (\N{CJK UNIFIED IDEOGRAPH-6492}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 26031 (\N{CJK UNIFIED IDEOGRAPH-65AF}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 23526 (\N{CJK UNIFIED IDEOGRAPH-5BE6}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 32722 (\N{CJK UNIFIED IDEOGRAPH-7FD2}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 25934 (\N{CJK UNIFIED IDEOGRAPH-654E}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/3556828896.py:56: UserWarning: Glyph 25480 (\N{CJK UNIFIED IDEOGRAPH-6388}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz2_pca_scatter.png", dpi=150, bbox_inches="tight",
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 30041 (\N{CJK UNIFIED IDEOGRAPH-7559}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 32654 (\N{CJK UNIFIED IDEOGRAPH-7F8E}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 30889 (\N{CJK UNIFIED IDEOGRAPH-78A9}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22763 (\N{CJK UNIFIED IDEOGRAPH-58EB}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27472 (\N{CJK UNIFIED IDEOGRAPH-6B50}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27743 (\N{CJK UNIFIED IDEOGRAPH-6C5F}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 36938 (\N{CJK UNIFIED IDEOGRAPH-904A}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 30028 (\N{CJK UNIFIED IDEOGRAPH-754C}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 36027 (\N{CJK UNIFIED IDEOGRAPH-8CBB}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 29273 (\N{CJK UNIFIED IDEOGRAPH-7259}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 31185 (\N{CJK UNIFIED IDEOGRAPH-79D1}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23494 (\N{CJK UNIFIED IDEOGRAPH-5BC6}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24076 (\N{CJK UNIFIED IDEOGRAPH-5E0C}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26681 (\N{CJK UNIFIED IDEOGRAPH-6839}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26371 (\N{CJK UNIFIED IDEOGRAPH-6703}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 33775 (\N{CJK UNIFIED IDEOGRAPH-83EF}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 30427 (\N{CJK UNIFIED IDEOGRAPH-76DB}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 38931 (\N{CJK UNIFIED IDEOGRAPH-9813}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 32769 (\N{CJK UNIFIED IDEOGRAPH-8001}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21733 (\N{CJK UNIFIED IDEOGRAPH-54E5}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25958 (\N{CJK UNIFIED IDEOGRAPH-6566}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20689 (\N{CJK UNIFIED IDEOGRAPH-50D1}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12290 (\N{IDEOGRAPHIC FULL STOP}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26481 (\N{CJK UNIFIED IDEOGRAPH-6771}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23448 (\N{CJK UNIFIED IDEOGRAPH-5B98}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22806 (\N{CJK UNIFIED IDEOGRAPH-5916}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 33258 (\N{CJK UNIFIED IDEOGRAPH-81EA}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27915 (\N{CJK UNIFIED IDEOGRAPH-6D0B}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20022 (\N{CJK UNIFIED IDEOGRAPH-4E36}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34389 (\N{CJK UNIFIED IDEOGRAPH-8655}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34349 (\N{CJK UNIFIED IDEOGRAPH-862D}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21531 (\N{CJK UNIFIED IDEOGRAPH-541B}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 37096 (\N{CJK UNIFIED IDEOGRAPH-90E8}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27954 (\N{CJK UNIFIED IDEOGRAPH-6D32}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34203 (\N{CJK UNIFIED IDEOGRAPH-859B}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20961 (\N{CJK UNIFIED IDEOGRAPH-51E1}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20126 (\N{CJK UNIFIED IDEOGRAPH-4E9E}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 33289 (\N{CJK UNIFIED IDEOGRAPH-8209}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 38463 (\N{CJK UNIFIED IDEOGRAPH-963F}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 28023 (\N{CJK UNIFIED IDEOGRAPH-6D77}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25746 (\N{CJK UNIFIED IDEOGRAPH-6492}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26031 (\N{CJK UNIFIED IDEOGRAPH-65AF}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23526 (\N{CJK UNIFIED IDEOGRAPH-5BE6}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 32722 (\N{CJK UNIFIED IDEOGRAPH-7FD2}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25934 (\N{CJK UNIFIED IDEOGRAPH-654E}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 25480 (\N{CJK UNIFIED IDEOGRAPH-6388}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 32822 (\N{CJK UNIFIED IDEOGRAPH-8036}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 36335 (\N{CJK UNIFIED IDEOGRAPH-8DEF}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
# Saved → viz2_pca_scatter.png

# %% [markdown]
# ## Visualisation 3 — Similarity Network Graph
# Each query term is the hub; edges connect it to neighbours with thickness and opacity scaled by similarity score.
# Shared neighbours (words appearing near multiple queries) naturally emerge as cross-cluster bridges.

# %%
# ── build graph ───────────────────────────────────────────────────────────────
# Use top-N neighbours; use fewer for a cleaner graph
GRAPH_TOPN = 12

G = nx.Graph()
edge_attrs = {}  # (u,v) -> {weight, color}

for term, color in zip(valid_terms, PALETTE):
    G.add_node(term, kind="query", query=term, color=color)
    for sim_term, score in model.most_similar(term, topn=GRAPH_TOPN):
        if not G.has_node(sim_term):
            G.add_node(sim_term, kind="neighbor", query=term,
                       color=PALETTE[valid_terms.index(term)])
        G.add_edge(term, sim_term, weight=score, query=term, color=color)

# ── layout ────────────────────────────────────────────────────────────────────
# Seed for reproducibility; spring layout with high k spreads nodes nicely
pos = nx.spring_layout(G, seed=7, k=2.8 / np.sqrt(G.number_of_nodes()),
                       iterations=120, weight="weight")

# ── draw ──────────────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(13, 9))
fig.suptitle("Semantic Similarity Network", fontsize=14)

# edges: colour by query term, thickness / alpha by weight
weights = [G[u][v]["weight"] for u, v in G.edges()]
w_arr = np.array(weights)
norm_w = (w_arr - w_arr.min()) / (w_arr.max() - w_arr.min() + 1e-9)

for (u, v), nw, w in zip(G.edges(), norm_w, weights):
    ec = G[u][v]["color"]
    nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], ax=ax,
                           width=0.5 + 2.5 * nw,
                           alpha=0.25 + 0.55 * nw,
                           edge_color=[ec])

# neighbour nodes
nbr_nodes = [n for n, d in G.nodes(data=True) if d["kind"] == "neighbor"]
nbr_colors = [G.nodes[n]["color"] for n in nbr_nodes]
nx.draw_networkx_nodes(G, pos, nodelist=nbr_nodes, ax=ax,
                       node_color=nbr_colors, node_size=140,
                       alpha=0.75, linewidths=0)

# query nodes on top
for term, color in zip(valid_terms, PALETTE):
    nx.draw_networkx_nodes(G, pos, nodelist=[term], ax=ax,
                           node_color=[color], node_size=700,
                           linewidths=1.5, edgecolors="#ffffff")

# labels: query terms bold & larger
query_labels  = {n: n for n in valid_terms}
nbr_labels    = {n: n for n in nbr_nodes}

nx.draw_networkx_labels(G, pos, labels=query_labels, ax=ax,
                        font_size=10, font_weight="bold", font_color="#ffffff")
nx.draw_networkx_labels(G, pos, labels=nbr_labels, ax=ax,
                        font_size=6.5, font_color="#c9d1d9")

legend_handles = [mpatches.Patch(facecolor=PALETTE[i], label=t)
                  for i, t in enumerate(valid_terms)]
ax.legend(handles=legend_handles, title="Query term", loc="lower left",
          framealpha=0.3, fontsize=9, title_fontsize=9)

ax.axis("off")
plt.tight_layout()
plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
            facecolor=fig.get_facecolor())
plt.show()
print("Saved → viz3_network_graph.png")
# Out:
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:65: UserWarning: Glyph 30041 (\N{CJK UNIFIED IDEOGRAPH-7559}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:65: UserWarning: Glyph 32654 (\N{CJK UNIFIED IDEOGRAPH-7F8E}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:65: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:65: UserWarning: Glyph 36938 (\N{CJK UNIFIED IDEOGRAPH-904A}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 30041 (\N{CJK UNIFIED IDEOGRAPH-7559}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 32654 (\N{CJK UNIFIED IDEOGRAPH-7F8E}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 36938 (\N{CJK UNIFIED IDEOGRAPH-904A}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 30889 (\N{CJK UNIFIED IDEOGRAPH-78A9}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 22763 (\N{CJK UNIFIED IDEOGRAPH-58EB}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 27472 (\N{CJK UNIFIED IDEOGRAPH-6B50}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 27743 (\N{CJK UNIFIED IDEOGRAPH-6C5F}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 30028 (\N{CJK UNIFIED IDEOGRAPH-754C}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 36027 (\N{CJK UNIFIED IDEOGRAPH-8CBB}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 33775 (\N{CJK UNIFIED IDEOGRAPH-83EF}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 12290 (\N{IDEOGRAPHIC FULL STOP}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 32769 (\N{CJK UNIFIED IDEOGRAPH-8001}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 26481 (\N{CJK UNIFIED IDEOGRAPH-6771}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 23448 (\N{CJK UNIFIED IDEOGRAPH-5B98}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 22806 (\N{CJK UNIFIED IDEOGRAPH-5916}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 34389 (\N{CJK UNIFIED IDEOGRAPH-8655}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 34349 (\N{CJK UNIFIED IDEOGRAPH-862D}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 21531 (\N{CJK UNIFIED IDEOGRAPH-541B}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 37096 (\N{CJK UNIFIED IDEOGRAPH-90E8}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 27954 (\N{CJK UNIFIED IDEOGRAPH-6D32}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 34203 (\N{CJK UNIFIED IDEOGRAPH-859B}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 20961 (\N{CJK UNIFIED IDEOGRAPH-51E1}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 20126 (\N{CJK UNIFIED IDEOGRAPH-4E9E}) missing from font(s) DejaVu Sans.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 30041 (\N{CJK UNIFIED IDEOGRAPH-7559}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 32654 (\N{CJK UNIFIED IDEOGRAPH-7F8E}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /var/folders/d9/m0pd23td2d5cf3cpftrcpy5r0000gp/T/ipykernel_6286/95724708.py:66: UserWarning: Glyph 36938 (\N{CJK UNIFIED IDEOGRAPH-904A}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig("viz3_network_graph.png", dpi=150, bbox_inches="tight",
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 30041 (\N{CJK UNIFIED IDEOGRAPH-7559}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 32654 (\N{CJK UNIFIED IDEOGRAPH-7F8E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 36938 (\N{CJK UNIFIED IDEOGRAPH-904A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 30889 (\N{CJK UNIFIED IDEOGRAPH-78A9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22763 (\N{CJK UNIFIED IDEOGRAPH-58EB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27472 (\N{CJK UNIFIED IDEOGRAPH-6B50}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27743 (\N{CJK UNIFIED IDEOGRAPH-6C5F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 30028 (\N{CJK UNIFIED IDEOGRAPH-754C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 36027 (\N{CJK UNIFIED IDEOGRAPH-8CBB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 33775 (\N{CJK UNIFIED IDEOGRAPH-83EF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12290 (\N{IDEOGRAPHIC FULL STOP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 32769 (\N{CJK UNIFIED IDEOGRAPH-8001}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26481 (\N{CJK UNIFIED IDEOGRAPH-6771}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23448 (\N{CJK UNIFIED IDEOGRAPH-5B98}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22806 (\N{CJK UNIFIED IDEOGRAPH-5916}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34389 (\N{CJK UNIFIED IDEOGRAPH-8655}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34349 (\N{CJK UNIFIED IDEOGRAPH-862D}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21531 (\N{CJK UNIFIED IDEOGRAPH-541B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 37096 (\N{CJK UNIFIED IDEOGRAPH-90E8}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 27954 (\N{CJK UNIFIED IDEOGRAPH-6D32}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34203 (\N{CJK UNIFIED IDEOGRAPH-859B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20961 (\N{CJK UNIFIED IDEOGRAPH-51E1}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20126 (\N{CJK UNIFIED IDEOGRAPH-4E9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Saved → viz3_network_graph.png

# %% [markdown]
# ## Bonus — Multi-word Query
# Average the vectors of all supplied words and retrieve nearest neighbours.

# %%
model = load_facebook_vectors("/Users/carmand/Desktop/RS/enp_embeddings/toastynews.bin")
phrase = ["returned", "student"]
valid_phrase = [w for w in phrase if w in model]

if valid_phrase:
    results = model.most_similar(positive=valid_phrase, topn=20)
    terms_mw, scores_mw = zip(*results)

    fig, ax = plt.subplots(figsize=(7, 6))
    fig.suptitle(f'Multi-word query: {"+".join(valid_phrase)}', fontsize=12)

    bars = ax.barh(list(terms_mw)[::-1], list(scores_mw)[::-1],
                   color=PALETTE[3], alpha=0.85, height=0.65)
    for bar, val in zip(bars, list(scores_mw)[::-1]):
        ax.text(bar.get_width() + 0.002, bar.get_y() + bar.get_height() / 2,
                f"{val:.3f}", va="center", ha="left", fontsize=7.5, color="#8b949e")

    ax.set_xlabel("Cosine similarity")
    ax.set_xlim(min(scores_mw) - 0.02, max(scores_mw) + 0.04)
    ax.grid(axis="x", linestyle="--")
    ax.tick_params(axis="y", labelsize=8)
    ax.spines[["top", "right"]].set_visible(False)

    plt.tight_layout()
    plt.savefig("viz4_multiword_bar.png", dpi=150, bbox_inches="tight",
                facecolor=fig.get_facecolor())
    plt.show()
    print("Saved → viz4_multiword_bar.png")
else:
    print("None of the phrase words are in the vocabulary.")
# Out:
# Saved → viz4_multiword_bar.png
